# %% [markdown]
# # Warping ABA PCA clusters to Allen Brain Template

# %%
# %%bash
# module load afni/20.1.11
# cd /data/bioprotean/ABA/PCA/Kmeans_labels/to_ABT/
# @animal_warper -base allen_brain200.nii -input nclusters_fixed400.nii -ok_to_exist -outdir warp
# Out:
# ++ Making 'base' abbrev:
#    ... ORIG --> BASEORIG
# #++ align_epi_anat version: 1.62
# #++ turning off tshift, volume registration, resampling
# #++ turning off tshift, volume registration, resampling
# #Script is running (command trimmed):
#   3dAttribute DELTA ./nclusters_fixed400_shft.nii.gz
# #Script is running (command trimmed):
#   3dAttribute DELTA ./nclusters_fixed400_shft.nii.gz
# #Script is running:
#   3dAttribute DELTA /data/bioprotean/ABA/PCA/Kmeans_labels/to_ABT/allen_brain200.nii
# #++ Multi-cost is lpa+ZZ
# #++ Removing all the temporary files
# #Script is running:
#   \rm -f ./__tt_nclusters_fixed400_shft*
# #Script is running:
#   \rm -f ./__tt_allen_brain200*
# #Script is running (command trimmed):
#   3dcopy /data/bioprotean/ABA/PCA/Kmeans_labels/to_ABT/allen_brain200.nii ./__tt_allen_brain200+orig
# #Script is running (command trimmed):
#   3dinfo ./__tt_allen_brain200+orig | \grep 'Data Axes Tilt:'|\grep 'Oblique'
# ...
