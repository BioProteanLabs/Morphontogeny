# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/data/bioprotean/SVD/colocalization/results_py.csv', delimiter=',', index_col=0)
df.head()
# Out:
#    cluster1  cluster2  cluster3  cluster4  cluster5  cluster6  cluster7  \
# 1  0.013350       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.007400  0.023126       NaN       NaN       NaN       NaN       NaN
# 3  0.006881  0.026268  0.016661       NaN       NaN       NaN       NaN
# 4  0.015971  0.006524  0.029124  0.020221       NaN       NaN       NaN
# 5  0.016607  0.006519  0.016190  0.037131  0.019911       NaN       NaN
#
#    cluster8  cluster9  cluster10  ...  cluster41  cluster42  cluster43  \
# 1       NaN       NaN        NaN  ...        NaN        NaN        NaN
# 2       NaN       NaN        NaN  ...        NaN        NaN        NaN
# 3       NaN       NaN        NaN  ...        NaN        NaN        NaN
# 4       NaN       NaN        NaN  ...        NaN        NaN        NaN
# 5       NaN       NaN        NaN  ...        NaN        NaN        NaN
#
#    cluster44  cluster45  cluster46  cluster47  cluster48  cluster49  cluster50
# ...

# %%
sns.heatmap(df.iloc[20:30,20:30], annot=True)

# %%
df.iloc[9,:]
# Out:
# cluster1     0.040388
# cluster2     0.010096
# cluster3     0.015020
# cluster4     0.016672
# cluster5     0.003907
# cluster6     0.018936
# cluster7     0.014958
# cluster8     0.036419
# cluster9     0.014484
# cluster10    0.028767
# cluster11         NaN
# cluster12         NaN
# cluster13         NaN
# cluster14         NaN
# cluster15         NaN
# cluster16         NaN
# cluster17         NaN
# cluster18         NaN
# cluster19         NaN
# cluster20         NaN
# cluster21         NaN
# cluster22         NaN
# cluster23         NaN
# cluster24         NaN
# cluster25         NaN
# cluster26         NaN
# cluster27         NaN
# cluster28         NaN
# cluster29         NaN
# cluster30         NaN
# cluster31         NaN
# cluster32         NaN
# cluster33         NaN
# cluster34         NaN
# cluster35         NaN
# cluster36         NaN
# cluster37         NaN
# cluster38         NaN
# cluster39         NaN
# cluster40         NaN
# cluster41         NaN
# ...
