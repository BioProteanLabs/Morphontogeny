# %% [markdown]
# # Finding receptor genes

# %%
import numpy as np
import pandas as pd
import mygene
mg = mygene.MyGeneInfo()

# %%
topgenes_df = pd.read_csv('/data/bioprotean/GO/top_genes.csv')

# %%
topgenes_df.head()
# Out:
#    Old Index           Gene  Entrez ID             Image Series URL  \
# 0          0  0610007P14Rik      58520  0610007P14Rik/70927828.html
# 1          1  0610010D24Rik      68339  0610010D24Rik/74363346.html
# 2          2  0610010O12Rik      66060  0610010O12Rik/75079788.html
# 3          3  0610011I04Rik      66058  0610011I04Rik/75650863.html
# 4          5  0610042C05Rik      66084  0610042C05Rik/77371805.html
#
#    Used in analysis?        ID
# 0                  1  70927828
# 1                  1  74363346
# 2                  1  75079788
# 3                  1  75650863
# 4                  1  77371805

# %%
for i in range(topgenes_df.shape[0]):
    try:
        topgenes_df.gName[i] = mg.getgene(topgenes_df['Entrez ID'][i], fields='name')['name']
    except:
        continue
# Out:
# /packages/7x/anaconda3/5.3.0/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
topgenes_df
# Out:
#       Old Index           Gene  Entrez ID             Image Series URL  \
# 0             0  0610007P14Rik      58520  0610007P14Rik/70927828.html
# 1             1  0610010D24Rik      68339  0610010D24Rik/74363346.html
# 2             2  0610010O12Rik      66060  0610010O12Rik/75079788.html
# 3             3  0610011I04Rik      66058  0610011I04Rik/75650863.html
# 4             5  0610042C05Rik      66084  0610042C05Rik/77371805.html
# ...         ...            ...        ...                          ...
# 2936       3034          Zmym2      76007          Zmym2/73925714.html
# 2937       3035        Zmynd11      66505        Zmynd11/70743906.html
# 2938       3036          Znrf1     170737          Znrf1/74581382.html
# 2939       3037         Zswim6      67263         Zswim6/75146003.html
# 2940       3038            Zyx      22793            Zyx/71670710.html
#
#       Used in analysis?        ID  \
# 0                     1  70927828
# 1                     1  74363346
# ...

# %%
topgenes_df.to_csv('/data/bioprotean/GO/topgeneswithnames.csv')

# %%
topgenes_df[topgenes_df.gName.str.contains('receptor')].to_csv('/data/bioprotean/GO/receptors_only.csv')
