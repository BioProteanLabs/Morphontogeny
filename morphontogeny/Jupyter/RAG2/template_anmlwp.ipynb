# %% [markdown]
# This is to make a template using the @animal_warper function.

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/MWT_Morphometry/12345/
# @animal_warper -base 5.nii -input avg1234+orig -ok_to_exist -outdir anml_wp
# Out:
# ++ Making 'base' abbrev:
#    ... ORIG --> BASEORIG
# #++ align_epi_anat version: 1.62
# #++ turning off tshift, volume registration, resampling
# #++ turning off tshift, volume registration, resampling
# #Script is running (command trimmed):
#   3dAttribute DELTA ./avg1234_shft.nii.gz
# #Script is running (command trimmed):
#   3dAttribute DELTA ./avg1234_shft.nii.gz
# #Script is running:
#   3dAttribute DELTA /home/mabbasi6/morphometry/MWT_Morphometry/12345/5.nii
# #++ Multi-cost is lpa+ZZ
# #++ Removing all the temporary files
# #Script is running:
#   \rm -f ./__tt_avg1234_shft*
# #Script is running:
#   \rm -f ./__tt_5*
# #Script is running (command trimmed):
#   3dcopy /home/mabbasi6/morphometry/MWT_Morphometry/12345/5.nii ./__tt_5+orig
# #Script is running (command trimmed):
#   3dinfo ./__tt_5+orig | \grep 'Data Axes Tilt:'|\grep 'Oblique'
# #++ Dataset /home/mabbasi6/morphometry/MWT_Morphometry/12345/anml_wp/__tt_5+orig is not oblique
# #Script is running (command trimmed):
# ...

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/MWT_Morphometry/12345/anml_wp/
# 3dcalc -a 5.nii.gz -b avg1234_warp2std_ns.nii.gz -expr '(a+b)/2' -prefix MWT_template
# Out:
# 3dcalc: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ++ 3dcalc: AFNI version=AFNI_20.1.11 (May 28 2020) [64-bit]
# ++ Authored by: A cast of thousands
# ++ Output dataset ./MWT_template+orig.BRIK
