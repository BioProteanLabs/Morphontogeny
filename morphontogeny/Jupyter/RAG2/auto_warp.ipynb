# %% [raw]
# This is to make a pipeline for the non-linear warp using auto_warp.py (which in fact uses 3dQwarp).
# The warp is slow, but does a great job!
# The pipeline is designed to take files into BRIK format and then, deal with them.
# Becuase not all AFNI functions handle NIFTI well, and yeah, that sucks.

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/correlation/rotation/
# input='1ttest_rsbflip.nii'
# base='brain.nii'
# @Align_Centers \
#     -base $base \
#     -dset $input \
#     -prefix 1ttest_rsbflipac.nii
# Out:
# ParseName: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ParseName: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ParseName: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# 3dAttribute: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ...

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/correlation/rotation/
# input='brain_flip_ac.nii'
# base='brain.nii'
# auto_warp.py \
#     -base $base \
#     -input $input \
#     -qworkhard 0 2 \
#     -skip_affine yes \
#     -qw_opts -maxlev 09 -iwarp \
#     -output_dir awp

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/correlation/rotation/
# input='brain2_ac.nii'
# base='brain.nii'
# 3dAllineate \
#     -base $base \
#     -source $input \
#     -1Dmatrix_save affine_matrix \
#     -cmass -cost lpa -mi -twopass \
#     -automask -num_rtb 2000 \
#     -warp affine_general \
#     -prefix MWT_aff.nii
# auto_warp.py \
#     -base $base \
#     -input MWT_aff.nii \
#     -qworkhard 0 2 \
#     -skip_affine yes \
#     -qw_opts -maxlev 09 -iwarp \
#     -output_dir awp_ac
# Out:
# #++ auto_warp.py version: 0.04
# # Output directory /home/mabbasi6/morphometry/MWT_Morphometry/allen/rotate/awp_ac/
# #Script is running:
#   mkdir /home/mabbasi6/morphometry/MWT_Morphometry/allen/rotate/awp_ac/
# cd /home/mabbasi6/morphometry/MWT_Morphometry/allen/rotate/awp_ac/
# #Script is running (command trimmed):
#   3dcopy /home/mabbasi6/morphometry/MWT_Morphometry/allen/rotate/MWT_aff.nii ./anat.nii
# #Script is running (command trimmed):
#   3dUnifize -GM -input ./anat.nii -prefix ./anat.un.nii
# #Script is running (command trimmed):
#   3dcopy /home/mabbasi6/morphometry/MWT_Morphometry/allen/rotate/allen_75.nii ./base.nii
# #Script is running (command trimmed):
#   3dAttribute DELTA ./anat.un.nii
# #Script is running (command trimmed):
#   3dAttribute DELTA ./base.nii
# 0.075000 0.075000
# #Script is running (command trimmed):
#   3dinfo -same_grid ./anat.un.nii ./base.nii
# ...

# %% [raw]
# This is to test the linear parameters and the warps on the annotations image.

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/MKO_Morphometry/Allen/auto_warp/orig/
# input='annot_ac+orig'
# base='MWT_template_res.nii'
# lwp='affine_matrix.aff12.1D'
# 3dAllineate \
#     -master $base \
#     -source $input \
#     -1Dparam_apply $lwp \
#     -prefix annot_aff
# Out:
# 3dAllineate: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ++ 3dAllineate: AFNI version=AFNI_20.1.11 (May 28 2020) [64-bit]
# ++ Authored by: Zhark the Registrator
# ++ Source dataset: ./annot_ac+orig.HEAD
# ++ Base dataset:   (not given)
# ++ Loading datasets into memory
#  +        -cmass x y z shifts =    0.000    0.000    0.000
#  +  shift search range is +/- =    3.643    4.221    2.552
# ++ OpenMP thread count = 1
# ++ ========== Applying transformation to 1 sub-bricks ==========
# ++ Output dataset ./annot_aff+orig.BRIK
# ++ 3dAllineate: total CPU time = 0.0 sec  Elapsed = 6.0
# ++ ###########################################################

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/MKO_Morphometry/Allen/auto_warp/orig/
# input='annot_ranked+orig'
# base='MWT_template_res.nii'
# @Align_Centers -base $base -dset $input -prefix annot_ac
# Out:
# ParseName: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ParseName: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# afni: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ParseName: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# 3dAttribute: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ...

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/MKO_Morphometry/Allen/auto_warp/orig/
# input='annot_ac+orig'
# base='MWT_template_res.nii'
# warp='anat.un.qw_WARP.nii'
# 3dNwarpApply \
#     -master $base \
#     -source $input \
#     -nwarp $warp \
#     -prefix annot_wp
# Out:
# 3dNwarpApply: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# ++ 3dNwarpApply: AFNI version=AFNI_20.1.11 (May 28 2020) [64-bit]
# ++ Authored by: Zhark the Warped
# ++ -master dataset is 'MWT_template_res.nii'
# ++ opened source dataset 'annot_ac+orig'
# ++ Processing -nwarp
# ++ Warping:.Z
# ++ Output dataset ./annot_wp+orig.BRIK
# ++ total Elapsed time = 17.9 sec
