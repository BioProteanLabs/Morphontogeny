# %% [markdown]
# This is to try skull stripping using @animal_warper

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/Henkelman/Skullstrip/
# @animal_warper -base RsMDorr+orig -input 2522_MKO.nii -ok_to_exist -outdir warp
# Out:
# ++ Making 'base' abbrev:
#    ... ORIG --> BASEORIG
# #++ align_epi_anat version: 1.62
# #++ turning off tshift, volume registration, resampling
# #++ turning off tshift, volume registration, resampling
# #Script is running (command trimmed):
#   3dAttribute DELTA ./2522_MKO_shft.nii.gz
# #Script is running (command trimmed):
#   3dAttribute DELTA ./2522_MKO_shft.nii.gz
# #Script is running:
#   3dAttribute DELTA /home/mabbasi6/morphometry/Henkelman/Skullstrip/RsMDorr+orig
# #++ Multi-cost is lpa+ZZ
# #++ Removing all the temporary files
# #Script is running:
#   \rm -f ./__tt_2522_MKO_shft*
# #Script is running:
#   \rm -f ./__tt_RsMDorr*
# #Script is running (command trimmed):
#   3dcopy /home/mabbasi6/morphometry/Henkelman/Skullstrip/RsMDorr+orig ./__tt_RsMDorr+orig
# #Script is running (command trimmed):
#   3dinfo ./__tt_RsMDorr+orig | \grep 'Data Axes Tilt:'|\grep 'Oblique'
# #++ Dataset /home/mabbasi6/morphometry/Henkelman/Skullstrip/warp/__tt_RsMDorr+orig is not oblique
# ...

# %% [markdown]
# This is to try it using 3dSkullstrip

# %%
# %%bash
# module load afni/20.1.11
# cd /home/mabbasi6/morphometry/Henkelman/Skullstrip/
# 3dSkullStrip -input 2522_MKO.nii -rat -use_edge -prefix 2522_3dSSedge
# Out:
# 3dSkullStrip: /packages/7x/anaconda3/5.3.0/lib/libuuid.so.1: no version information available (required by /lib64/libSM.so.6)
# *+ WARNING: NO spatial transform (neither qform nor sform), in NIfTI file '/home/mabbasi6/morphometry/Henkelman/Skullstrip/2522_MKO.nii'
# The intensity in the output dataset is a modified version
# of the intensity in the input volume.
# To obtain a masked version of the input with identical values inside
# the brain, you can either use 3dSkullStrip's -orig_vol option
# or run the following command:
#   3dcalc -a 2522_MKO.nii -b ./2522_3dSSedge+orig -expr 'a*step(b)' \
#          -prefix ./2522_3dSSedge_orig_vol
# to generate a new masked version of the input.
